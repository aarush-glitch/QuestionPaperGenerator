# %% [markdown]
# # 1. Install Required Packages
# Install Node.js, npm, and create-react-app to scaffold a modern React frontend. Use npm or yarn to install additional dependencies for UI, animations, and HTTP requests.
